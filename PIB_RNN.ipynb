# %% [markdown]
# <a href="https://colab.research.google.com/github/Elvio1980/Elvio1980/blob/main/PIB_RNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Pre processamento

# %% [markdown]
# ##Carga das bibliotecas
#
# Bibliotecas utilizadas
# 1. Tensorfow: *O TensorFlow é uma biblioteca de código aberto desenvolvida pelo Google para computação numérica e machine learning. É amplamente utilizada para construir e treinar modelos de machine learning, incluindo redes neurais profundas, em uma variedade de tarefas, como classificação, reconhecimento de imagem, processamento de linguagem natural e muito mais. O TensorFlow oferece uma estrutura flexível e escalável para criar modelos complexos e realizar cálculos eficientes em CPUs, GPUs e até mesmo em hardware especializado, como TPUs (Tensor Processing Units).*

# %%
import tensorflow as tf
import pandas as pd
import numpy as np

# %% [markdown]
# ##Carregar o XLSX

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a265112f-6618-4730-837f-aca207e11829" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a265112f-6618-4730-837f-aca207e11829">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ##Exibir cabeçalho

# %%
import pandas as pd
dados = pd.read_excel("PIBdosMunicipios2010_2021.xlsx")
print(dados.head)
# Out:
# <bound method NDFrame.head of         Ano  Código da Grande Região Nome da Grande Região  \
# 0      2010                        1                 Norte
# 1      2010                        1                 Norte
# 2      2010                        1                 Norte
# 3      2010                        1                 Norte
# 4      2010                        1                 Norte
# ...     ...                      ...                   ...
# 66820  2021                        5          Centro-oeste
# 66821  2021                        5          Centro-oeste
# 66822  2021                        5          Centro-oeste
# 66823  2021                        5          Centro-oeste
# 66824  2021                        5          Centro-oeste
#
#        Código da Unidade da Federação Sigla da Unidade da Federação  \
# 0                                  11                            RO
# 1                                  11                            RO
# ...

# %% [markdown]
# ##Mantem apenas as colunas: Ano, Região, Estado, Município, Produto interno bruto e Produto interno bruto per capita.

# %%
import pandas as pd
dados = pd.read_excel("PIBdosMunicipios2010_2021.xlsx")
colunas_a_manter = [0, 2, 5, 7, 38, 39]
novo_dados = dados.iloc[:,colunas_a_manter]
